# %%
# %fs ls dbfs:/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks/</td><td>databricks/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/dbacademy/</td><td>dbacademy/</td><td>0</td></tr><tr><td>dbfs:/default/</td><td>default/</td><td>0</td></tr><tr><td>dbfs:/loan_by_state.parquet/</td><td>loan_by_state.parquet/</td><td>0</td></tr><tr><td>dbfs:/local_disk0/</td><td>local_disk0/</td><td>0</td></tr><tr><td>dbfs:/ml/</td><td>ml/</td><td>0</td></tr><tr><td>dbfs:/mnt/</td><td>mnt/</td><td>0</td></tr><tr><td>dbfs:/tmp/</td><td>tmp/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
CREATE DATABASE IF NOT EXISTS dbacademy;
USE dbacademy;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
sqlContext.setConf("spark.sql.shuffle.partitions", spark.sparkContext.defaultParallelism)
#by default Spark creates 200 files 
#number of partitions should match the number of clusters for optimum usage of clusters
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#connection to AWS s3 and mounting the files to hdfs
import urllib
access_key = "access_key"
secret_key = "secret_key"
s_s=urllib.parse.quote(secret_key,"")
bucket_name = "bucket_name"
mount_name = "mount_name"
dbutils.fs.mount("s3n://%s:%s@%s" % (access_key, s_s, bucket_name), "/mnt/%s" % mount_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     97</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 98</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     99</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.8.1-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o264.mount.
# : java.lang.IllegalArgumentException: The bucket name parameter must be specified when requesting a bucket&#39;s location
# 	at com.amazonaws.services.s3.AmazonS3Client.rejectNull(AmazonS3Client.java:3850)
# 	at com.amazonaws.services.s3.AmazonS3Client.getBucketLocation(AmazonS3Client.java:994)
# 	at com.amazonaws.services.s3.AmazonS3Client.getBucketLocation(AmazonS3Client.java:1006)
# 	at com.databricks.s3a.S3AFileSystem.setEndpointByAutoDetectedRegion(S3AFileSystem.java:451)
# 	at com.databricks.s3a.S3AFileSystem.setEndpoint(S3AFileSystem.java:438)
# 	at com.databricks.s3a.S3AFileSystem.initialize(S3AFileSystem.java:298)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.mount(DBUtilsCore.scala:416)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">IllegalArgumentException</span>                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-897846287922062&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span> bucket_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;bucket_name&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> mount_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;mount_name&#34;</span>
# <span class="ansi-green-fg">----&gt; 8</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>mount<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;s3n://%s:%s@%s&#34;</span> <span class="ansi-blue-fg">%</span> <span class="ansi-blue-fg">(</span>access_key<span class="ansi-blue-fg">,</span> s_s<span class="ansi-blue-fg">,</span> bucket_name<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;/mnt/%s&#34;</span> <span class="ansi-blue-fg">%</span> mount_name<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1587438044699-0/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    298</span>             <span class="ansi-green-fg">def</span> f_with_exception_handling<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>args<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    299</span>                 <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 300</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>args<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    301</span>                 <span class="ansi-green-fg">except</span> Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    302</span>                     <span class="ansi-green-fg">class</span> ExecutionError<span class="ansi-blue-fg">(</span>Exception<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1587438044699-0/dbutils.py</span> in <span class="ansi-cyan-fg">mount</span><span class="ansi-blue-fg">(self, source, mount_point, encryption_type, owner, extra_configs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    392</span>             return self.print_return(self.dbcore.mount(source, mount_point,
# <span class="ansi-green-intense-fg ansi-bold">    393</span>                                                        encryption_type<span class="ansi-blue-fg">,</span> owner<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-fg">--&gt; 394</span><span class="ansi-red-fg">                                                        java_extra_configs))
# </span><span class="ansi-green-intense-fg ansi-bold">    395</span>
# <span class="ansi-green-intense-fg ansi-bold">    396</span>         <span class="ansi-blue-fg">@</span>prettify_exception_message
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.8.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1284</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1285</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1286</span><span class="ansi-

# %%
# %fs rm -r dbfs:/mnt/training/healthcare/silver/recordings_parsed
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>

# %%
source_dir = "dbfs:/mnt/training/healthcare/"

basePath = "dbfs:/dbacademy/streaming-delta"

streamingPath          = basePath + "/source"
bronzePath             = basePath + "/bronze"
recordingsParsedPath   = basePath + "/silver/recordings_parsed"
recordingsEnrichedPath = basePath + "/silver/recordings_enriched"
dailyAvgPath           = basePath + "/gold/dailyAvg"

checkpointPath               = basePath + "/checkpoints"
bronzeCheckpoint             = basePath + "/checkpoints/bronze"
recordingsParsedCheckpoint   = basePath + "/checkpoints/recordings_parsed"
recordingsEnrichedCheckpoint = basePath + "/checkpoints/recordings_enriched"
dailyAvgCheckpoint           = basePath + "/checkpoints/dailyAvgPath"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.rm(basePath, True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
class FileArrival:
  def __init__(self):
    self.source = source_dir + "/tracker/streaming/"
    self.userdir = streamingPath + "/"
    self.curr_mo = 1
    
  def arrival(self, continuous=False):
    if self.curr_mo > 12:
      print("Data source exhausted\n")
    elif continuous == True:
      while self.curr_mo <= 12:
        curr_file = f"{self.curr_mo:02}.json"
        dbutils.fs.cp(self.source + curr_file, self.userdir + curr_file)
        self.curr_mo += 1
    else:
      curr_file = f"{str(self.curr_mo).zfill(2)}.json"
      dbutils.fs.cp(self.source + curr_file, self.userdir + curr_file)
      self.curr_mo += 1
      
NewFile = FileArrival()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
NewFile.arrival()
display(dbutils.fs.ls(streamingPath))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/dbacademy/streaming-delta/source/01.json</td><td>01.json</td><td>506710</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/02.json</td><td>02.json</td><td>711589</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/03.json</td><td>03.json</td><td>1652829</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/04.json</td><td>04.json</td><td>1614958</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/05.json</td><td>05.json</td><td>971481</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/06.json</td><td>06.json</td><td>811543</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/07.json</td><td>07.json</td><td>2004546</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/08.json</td><td>08.json</td><td>1854379</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/09.json</td><td>09.json</td><td>1288572</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/10.json</td><td>10.json</td><td>1202012</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/11.json</td><td>11.json</td><td>641042</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/source/12.json</td><td>12.json</td><td>490422</td></tr></tbody></table></div>

# %%
(spark.readStream
  .format("text")
  .schema("data STRING")
  .option("maxFilesPerTrigger", 1)  # This is used for testing to simulate 1 file arriving at a time.  Generally, don't set this in production.
  .load(streamingPath)
  .createOrReplaceTempView("recordings_raw_temp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW recordings_bronze_temp AS (
  SELECT current_timestamp() receipt_time, "recordings" dataset, *
  FROM recordings_raw_temp
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from recordings_raw_temp limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>data</th></tr></thead><tbody><tr><td>{"device_id":23,"heartrate":96.2296475916,"mrn":40580129,"time":1.578301316998366E9}</td></tr><tr><td>{"device_id":23,"heartrate":93.4442586858,"mrn":40580129,"time":1.5783022165450108E9}</td></tr></tbody></table></div>

# %%
# %sql
select * from recordings_bronze_temp limit 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>receipt_time</th><th>dataset</th><th>data</th></tr></thead><tbody><tr><td>2020-04-21T03:02:12.477+0000</td><td>recordings</td><td>{"device_id":23,"heartrate":96.2296475916,"mrn":40580129,"time":1.578301316998366E9}</td></tr><tr><td>2020-04-21T03:02:12.477+0000</td><td>recordings</td><td>{"device_id":23,"heartrate":93.4442586858,"mrn":40580129,"time":1.5783022165450108E9}</td></tr></tbody></table></div>

# %%
(spark.table("recordings_bronze_temp")
  .writeStream
  .format("delta")
  .option("checkpointLocation", bronzeCheckpoint)
  .outputMode("append")
  .start(bronzePath))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f1b39ad9b90&gt;</div>

# %%
# %fs ls dbfs:/dbacademy/streaming-delta/checkpoints/bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/dbacademy/streaming-delta/checkpoints/bronze/commits/</td><td>commits/</td><td>0</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/checkpoints/bronze/metadata</td><td>metadata</td><td>45</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/checkpoints/bronze/offsets/</td><td>offsets/</td><td>0</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/checkpoints/bronze/sources/</td><td>sources/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/dbacademy/streaming-delta/bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/dbacademy/streaming-delta/bronze/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/dbacademy/streaming-delta/bronze/part-00000-9a6fbe91-9426-4ca3-b18f-7bac3113836d-c000.snappy.parquet</td><td>part-00000-9a6fbe91-9426-4ca3-b18f-7bac3113836d-c000.snappy.parquet</td><td>181993</td></tr></tbody></table></div>

# %%
# Display how many records are in our table so we can watch it grow.

display(spark.readStream.format("delta").load(bronzePath).groupBy().count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count</th></tr></thead><tbody><tr><td>154767</td></tr></tbody></table></div>

# %%
(spark.readStream
       .format('delta')
       .load(bronzePath)
       .createOrReplaceTempView('bronze_unparsed_temp'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
create or replace temp view recordings_parsed_temp as 
  select json.device_id device_id, json.mrn mrn, json.heartrate heartrate, json.time time
  from (
    select from_json(data, "device_id Integer, mrn LONG, heartrate DOUBLE, time DOUBLE") json 
    from bronze_unparsed_temp
    where dataset = "recordings")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select count(*) from recordings_parsed_temp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>154767</td></tr></tbody></table></div>

# %%
(spark.table("recordings_parsed_temp")
  .writeStream
  .format("delta")
  .outputMode("append")
  .option("checkpointLocation", recordingsParsedCheckpoint)
  .start(recordingsParsedPath))
#As new files arrived and are parsed into the upstream table, this query will automatically pick up those changes.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f1b2387f0d0&gt;</div>

# %%
# %sql
select * from recordings_parsed_temp limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>mrn</th><th>heartrate</th><th>time</th></tr></thead><tbody><tr><td>23</td><td>40580129</td><td>96.2296475916</td><td>1.578301316998366E9</td></tr><tr><td>23</td><td>40580129</td><td>93.4442586858</td><td>1.5783022165450108E9</td></tr><tr><td>23</td><td>40580129</td><td>94.2165936572</td><td>1.5783031112630153E9</td></tr><tr><td>23</td><td>40580129</td><td>92.1651460706</td><td>1.5783040088954644E9</td></tr><tr><td>23</td><td>40580129</td><td>91.3190626151</td><td>1.5783049137983682E9</td></tr></tbody></table></div>

# %%
(spark
  .read
  .format("csv")
  .schema("mrn STRING, name STRING")
  .option("header", True)
  .load(f"{source_dir}/patient/patient_info.csv")
  .createOrReplaceTempView("pii"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from pii limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mrn</th><th>name</th></tr></thead><tbody><tr><td>23940128</td><td>Caitlin Garcia</td></tr><tr><td>18064290</td><td>Anthony Perez</td></tr><tr><td>95384990</td><td>Tanya Diaz</td></tr><tr><td>53057176</td><td>Autumn Calderon</td></tr><tr><td>96005424</td><td>Ronald Smith</td></tr></tbody></table></div>

# %%
(spark.readStream
  .format("delta")
  .load(recordingsParsedPath)
  .createOrReplaceTempView("silver_recordings_temp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
create or replace temp view recordings_w_pii as (
select device_id, a.mrn, b.name, cast(from_unixtime(time, "yyyy-mm-dd HH:MM:SS") as timestamp) time, heartrate 
from silver_recordings_temp a
inner join pii b
on a.mrn = b.mrn
where heartrate > 0)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from silver_recordings_temp limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>mrn</th><th>heartrate</th><th>time</th></tr></thead><tbody><tr><td>23</td><td>40580129</td><td>54.0122153343</td><td>1.5805153187989018E9</td></tr><tr><td>17</td><td>52804177</td><td>92.5136468131</td><td>1.580515375925345E9</td></tr><tr><td>37</td><td>65300842</td><td>52.1354807863</td><td>1.580515738293533E9</td></tr><tr><td>23</td><td>40580129</td><td>54.6477014191</td><td>1.5805162111955204E9</td></tr><tr><td>17</td><td>52804177</td><td>95.033344842</td><td>1.5805162887768724E9</td></tr></tbody></table></div>

# %%
display(spark.readStream.format("delta").load(recordingsEnrichedPath).groupBy().count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count</th></tr></thead><tbody><tr><td>146796</td></tr></tbody></table></div>

# %%
NewFile.arrival()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
(spark.table("recordings_w_pii")
  .writeStream
  .format("delta")
  .option("checkpointLocation", recordingsEnrichedCheckpoint)
  .outputMode("append")
  .start(recordingsEnrichedPath))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f1b238b5f90&gt;</div>

# %%
# %sql
select * from recordings_w_pii limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>mrn</th><th>name</th><th>time</th><th>heartrate</th></tr></thead><tbody><tr><td>23</td><td>40580129</td><td>Nicholas Spears</td><td>2020-01-01T00:02:00.000+0000</td><td>54.0122153343</td></tr><tr><td>17</td><td>52804177</td><td>Lynn Russell</td><td>2020-02-01T00:02:00.000+0000</td><td>92.5136468131</td></tr><tr><td>37</td><td>65300842</td><td>Samuel Hughes</td><td>2020-08-01T00:02:00.000+0000</td><td>52.1354807863</td></tr><tr><td>23</td><td>40580129</td><td>Nicholas Spears</td><td>null</td><td>54.6477014191</td></tr><tr><td>17</td><td>52804177</td><td>Lynn Russell</td><td>null</td><td>95.033344842</td></tr><tr><td>37</td><td>65300842</td><td>Samuel Hughes</td><td>null</td><td>57.3391541312</td></tr><tr><td>23</td><td>40580129</td><td>Nicholas Spears</td><td>null</td><td>56.6165053697</td></tr><tr><td>17</td><td>52804177</td><td>Lynn Russell</td><td>null</td><td>94.8134313932</td></tr><tr><td>37</td><td>65300842</td><td>Samuel Hughes</td><td>null</td><td>56.2469995332</td></tr><tr><td>23</td><td>40580129</td><td>Nicholas Spears</td><td>null</td><td>54.8372685558</td></tr></tbody></table></div>

# %%
# %sql
select approx_count_distinct(device_id) from recordings_w_pii
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>approx_count_distinct(device_id)</th></tr></thead><tbody><tr><td>34</td></tr></tbody></table></div>

# %%
(spark.readStream
  .format("delta")
  .load(recordingsEnrichedPath)
  .createOrReplaceTempView("recordings_enriched_temp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Creating GOLD table

# %%
# %sql
CREATE OR REPLACE TEMP VIEW patient_avg AS (
  SELECT mrn, name, MEAN(heartrate) avg_heartrate, date_trunc("DD", time) date
  FROM recordings_enriched_temp
  GROUP BY mrn, name, date_trunc("DD", time));
select * from patient_avg limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mrn</th><th>name</th><th>avg_heartrate</th><th>date</th></tr></thead><tbody><tr><td>18477029</td><td>Sean Brown</td><td>93.30678479798958</td><td>2020-07-24T00:00:00.000+0000</td></tr><tr><td>38299723</td><td>Cynthia Figueroa</td><td>67.94627273456668</td><td>2020-07-31T00:00:00.000+0000</td></tr><tr><td>41675882</td><td>Crystal Ho</td><td>75.24604093537916</td><td>2020-05-19T00:00:00.000+0000</td></tr><tr><td>53057176</td><td>Autumn Calderon</td><td>77.65769185481112</td><td>2020-01-21T00:00:00.000+0000</td></tr><tr><td>84682617</td><td>Kyle Cruz</td><td>97.17093971638748</td><td>2020-03-10T00:00:00.000+0000</td></tr></tbody></table></div>

# %% [markdown]
# #storing the GOLD table data in "DELTA" format
# #when there is aggregation of data (group by), that data should not be used for streaming out into files unless there is watermark() used along with the query

# %%
(spark.table("patient_avg")
  .writeStream
  .format("delta")
  .outputMode("complete")
  .option("checkpointLocation", dailyAvgCheckpoint)
  .trigger(once=True)
  .start(dailyAvgPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f1b238b5f10&gt;</div>

# %%
spark.sql("""
  DROP TABLE IF EXISTS daily_patient_avg
""")
spark.sql(f"""
  CREATE TABLE daily_patient_avg
  USING DELTA
  LOCATION '{dailyAvgPath}'
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: DataFrame[]</div>

# %%
# %sql
select count(mrn), mrn, MEAN(avg_heartrate)  from daily_patient_avg group by mrn order by mrn ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(mrn)</th><th>mrn</th><th>mean(avg_heartrate)</th></tr></thead><tbody><tr><td>30</td><td>18477029</td><td>93.37350982377507</td></tr><tr><td>16</td><td>20793791</td><td>83.24662359031231</td></tr><tr><td>28</td><td>38299723</td><td>74.86987454907126</td></tr><tr><td>61</td><td>40580129</td><td>84.55502699637036</td></tr><tr><td>37</td><td>46722881</td><td>86.591879954544</td></tr><tr><td>61</td><td>52804177</td><td>79.4291890902921</td></tr><tr><td>17</td><td>53962192</td><td>88.7334859443876</td></tr><tr><td>61</td><td>55827205</td><td>83.01916390348192</td></tr><tr><td>62</td><td>65300842</td><td>83.15765277869727</td></tr><tr><td>32</td><td>77385574</td><td>82.2459158438508</td></tr><tr><td>23</td><td>96005424</td><td>78.6303344941844</td></tr></tbody></table></div>

# %%
# %sql
SELECT * 
FROM daily_patient_avg
WHERE date BETWEEN "2020-01-17" AND "2020-01-31"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mrn</th><th>name</th><th>avg_heartrate</th><th>date</th></tr></thead><tbody><tr><td>40580129</td><td>Nicholas Spears</td><td>84.15279162254545</td><td>2020-01-18T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>90.19226846513912</td><td>2020-01-29T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>83.87160423675499</td><td>2020-01-26T00:00:00.000+0000</td></tr><tr><td>46722881</td><td>Rachel Contreras</td><td>96.9537797271</td><td>2020-01-26T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>87.28136623931819</td><td>2020-01-23T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>75.8357679881857</td><td>2020-01-31T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>88.7728571047</td><td>2020-01-25T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>87.6824889677381</td><td>2020-01-21T00:00:00.000+0000</td></tr><tr><td>46722881</td><td>Rachel Contreras</td><td>90.791853455</td><td>2020-01-24T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>82.43796936707</td><td>2020-01-28T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>77.72434753806087</td><td>2020-01-24T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>82.22439963429446</td><td>2020-01-30T00:00:00.000+0000</td></tr><tr><td>46722881</td><td>Rachel Contreras</td><td>88.8847002619</td><td>2020-01-30T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>85.51602798329131</td><td>2020-01-27T00:00:00.000+0000</td></tr><tr><td>46722881</td><td>Rachel Contreras</td><td>103.0913332272</td><td>2020-01-19T00:00:00.000+0000</td></tr><tr><td>46722881</td><td>Rachel Contreras</td><td>55.7236096444</td><td>2020-01-29T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>81.14354899974782</td><td>2020-01-22T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>81.40931700188</td><td>2020-01-17T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>82.5285459695318</td><td>2020-01-19T00:00:00.000+0000</td></tr><tr><td>40580129</td><td>Nicholas Spears</td><td>79.61769568677143</td><td>2020-01-20T00:00:00.000+0000</td></tr></tbody></table></div>

# %%
NewFile.arrival(continuous=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for s in spark.streams.active:
    s.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
